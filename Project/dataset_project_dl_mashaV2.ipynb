# %%
import gzip
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pycountry
from functools import lru_cache

# %%
file_path = 'links.tsv.gz'

with gzip.open(file_path, 'rt', encoding='utf-8') as file:
    df = pd.read_csv(file, sep='\t')

df
# Out:
#                id                label               nationality  \
# 0         Q261019      Isabelle Boulay                    canada
# 1         Q261049       Florencia Peña                 argentina
# 2         Q261064        Colin Fleming            united_kingdom
# 3         Q261069  Stig Inge Bjørnebye                    norway
# 4         Q261123        Alireza Haghi                      iran
# ...           ...                  ...                       ...
# 311596  Q61045974       Genc Sermaxhaj                    kosovo
# 311597  Q61093547       Alfonso Méndiz                     spain
# 311598  Q61163004     Carmen Aída Lazo               el_salvador
# 311599  Q61315007      Christin Walker  united_states_of_america
# 311600  Q61479333     Yury Ambrazevich                   belarus
#
#                date_of_birth  year_of_birth  \
# 0       1972-07-06T00:00:00Z           1972
# 1       1974-11-07T00:00:00Z           1974
# 2       1984-08-13T00:00:00Z           1984
# 3       1969-12-11T00:00:00Z           1969
# 4       1979-02-08T00:00:00Z           1979
# ...                      ...            ...
# 311596  1988-12-28T00:00:00Z           1988
# 311597  1961-07-21T00:00:00Z           1961
# 311598  1976-01-03T00:00:00Z           1976
# 311599  1988-05-03T00:00:00Z           1988
# 311600  1975-02-25T00:00:00Z           1975
#
#                                                     image
# 0       https://upload.wikimedia.org/wikipedia/commons...
# 1       https://upload.wikimedia.org/wikipedia/commons...
# 2       https://upload.wikimedia.org/wikipedia/commons...
# 3       https://upload.wikimedia.org/wikipedia/commons...
# 4       https://upload.wikimedia.org/wikipedia/commons...
# ...                                                   ...
# 311596  https://upload.wikimedia.org/wikipedia/commons...
# 311597  https://upload.wikimedia.org/wikipedia/commons...
# 311598  https://upload.wikimedia.org/wikipedia/commons...
# 311599  https://upload.wikimedia.org/wikipedia/commons...
# 311600  https://upload.wikimedia.org/wikipedia/commons...
#
# [311601 rows x 6 columns]

# %%
df.describe()
# Out:
#        year_of_birth
# count  311601.000000
# mean     1964.101880
# std        20.576533
# min      1920.000000
# 25%      1949.000000
# 50%      1966.000000
# 75%      1982.000000
# max      2233.000000

# %% [markdown]
# ### Посмотрим распределение целевой переменной

# %%
print(df['nationality'].unique().size)
np.unique(df['nationality'])
# Out:
# 405
# array(['afghan', 'afghanistan', 'afrika', 'albania', 'algeria',
#        'american_occupation_zone', 'american_samoa', 'americans',
#        'andorra', 'angola', 'anguilla', 'antigua_and_barbuda',
#        'argentina', 'armenia', 'armenian_soviet_socialist_republic',
#        'artsakh', 'aruba', 'assam', 'australia', 'austria', 'austrians',
#        'azerbaijan', 'azerbaijani', 'bahamas', 'bahrain', 'bangladesh',
#        'bangladeshis', 'barbados', 'beiyang_government', 'belarus',
#        'belgian_congo', 'belgium', 'belize', 'benin', 'bermuda', 'bhutan',
#        'bicycle_kick', 'bolivia', 'bosnia_and_herzegovina', 'bosniaks',
#        'botswana', 'brazi', 'brazil', 'brazil–uruguay_relations',
#        'british_empire', 'british_hong_kong',
#        'british_national_(overseas)', 'british_people', 'british_raj',
#        'british_somaliland', 'british_virgin_islands', 'brunei',
#        'bulgaria', 'bulgarian', 'burkina_faso', 'burundi',
#        'byelorussian_soviet_socialist_republic', 'cambodia', 'cameroon',
#        'canada', 'canadian_french', 'canadian_nationality_law',
#        'cape_verde', 'cayman_islands', 'central_african_republic', 'chad',
#        'chechens', 'chile', 'chileans', 'chilena', 'china',
#        'chinese_taipei', 'colombia', 'colombiana', 'colonial_nigeria',
#        'comoros', 'cook_islands', 'costa_rica',
#        'country_of_the_kingdom_of_the_netherlands', 'croacia', 'croatia',
#        'cuba', 'curaçao', 'cyprus', 'czech_republic',
#        'czechoslovak_republic', 'czechoslovak_socialist_republic',
#        'czechoslovakia', 'danish', 'democratic_republic_of_georgia',
#        'democratic_republic_of_the_congo', 'denmark', 'djibouti',
#        'dominica', 'dominican', 'dominican_republic', 'dominicana',
#        'dutch_east_indies', 'east_timor', 'ecuador',
#        'ecuador_national_football_team', 'egypt', 'egyptians',
#        'el_salvador', 'empire_of_japan', 'england', 'equatoria',
#        'equatorial_guinea', 'equestria', 'eritrea', 'estado_novo',
#        'estonia', 'eswatini', 'ethiopia', 'faroe_islands',
#        "federal_people's_republic_of_yugoslavia",
#        'federal_republic_of_yugoslavia', 'federated_states_of_micronesia',
#        'federation_of_rhodesia_and_nyasaland', 'fiji', 'filipino_people',
#        'finland', 'first_hungarian_republic', 'first_portuguese_republic',
#        'first_republic_of_austria', 'florence',
#        'francais_objective_specifique', 'france', 'francia',
#        'francoist_spain', 'française', 'french', 'french_algeria',
#        'gabon', 'gambia', 'georgia', 'georgian_soviet_socialist_republic',
#        'german', 'german_democratic_republic', 'german_empire', 'germans',
#        'germany', 'ghana', 'gibraltar', 'great_britain', 'greece',
#        'greenland', 'grenada', 'guam', 'guatemala', 'guernsey', 'guinea',
#        'guinea-bissau', 'guyana', 'haiti', 'honduras', 'hong_kong',
#        'hungarian', 'hungarians', 'hungary', 'iceland', 'india',
#        'indian_people', 'indonesia', 'iran', 'iraq', 'iraqi_kurdistan',
#        'ireland', 'irish', 'irish_republic', 'isle_of_man', 'israel',
#        'israelis', 'italians', 'italy', 'ivanteyevskaya_street',
#        'ivory_coast', 'jamaica', 'japan', 'japanese_people', 'jordan',
#        'katun', 'kazakhstan', 'kenya', 'kenya_colony',
#        'kingdom_of_afghanistan', 'kingdom_of_albania',
#        'kingdom_of_bulgaria', 'kingdom_of_denmark', 'kingdom_of_egypt',
#        'kingdom_of_greece', 'kingdom_of_hungary', 'kingdom_of_iraq',
#        'kingdom_of_italy', 'kingdom_of_mysore', 'kingdom_of_romania',
#        'kingdom_of_serbs,_croatians_and_slovenes',
#        'kingdom_of_the_netherlands', 'kingdom_of_yugoslavia', 'kiribati',
#        'korea', 'kosovo', 'kurdistan', 'kuwait', 'kuwait_city',
#        'kyrgyzstan', 'langnau_am_albis', 'laos', 'latvia', 'lebanon',
#        'lesotho', 'liberia', 'liberland', 'libya', 'liechtenstein',
#        'lithuania', 'lithuanian_soviet_socialist_republic', 'luxembourg',
#        'macau', 'madagascar', 'madrid', 'malawi', 'malays', 'malaysia',
#        'maldives', 'mali', 'malta', 'manchukuo', 'mandatory_palestine',
#        'marshall_islands', 'marítimo', 'mauritania', 'mauritius',
#        'mexicana', 'mexico', 'mexico_city', 'moldova', 'monaco',
#        'mongolia', "mongolian_people's_republic", 'montenegro',
#        'monterrey', 'montserrat', 'morocco', 'morocco_pavilion',
#        'mozambique', 'murcia', 'myanmar', 'méxico', 'namibia', 'nauru',
#        'nazareth', 'nazi_germany', 'nepal', 'nepali',
#        'netherlands_antilles', 'new_zealand', 'nicaragua', 'niger',
#        'nigeria', 'niue', 'north_korea', 'northern_ireland', 'norway',
#        'norwegian', 'nuu-chah-nulth', 'oaxaca', 'oman', 'pakistan',
#        'palau', 'palestine', 'palestinian_national_authority', 'panama',
#        'papua_new_guinea', 'paraguay', "people's_republic_of_bulgaria",
#        "people's_republic_of_china", "people's_republic_of_hungary",
#        "people's_republic_of_poland",
#        "people's_socialist_republic_of_albania", 'peru', 'perú',
#        'philippines', 'plastin', 'poland', 'portugal',
#        'protectorate_of_bohemia_and_moravia', 'puerto_rico', 'qatar',
#        'quebec', 'québec-comté', 'québécois', 'range_of_andia',
#        'republic_of_china_(1912–1949)', 'republic_of_cuba_(1902–59)',
#        'republic_of_macedonia', 'republic_of_the_congo',
#        'republic_of_upper_volta', 'republika_srpska',
#        'república_de_síria', 'rhodesia', 'romania',
#        "romanian_people's_republic", 'ruanda-urundi', 'russia',
#        'russian_soviet_federative_socialist_republic', 'rwanda',
#        'saint_kitts_and_nevis', 'saint_lucia',
#        'saint_vincent_and_the_grenadines', 'samoa', 'san_luis_potosí',
#        'san_marino', 'santo_domingo', 'saudi_arabia', 'scotland',
#        'second_polish_republic', 'senegal', 'serbia',
#        'serbia_and_montenegro', 'seychelles', 'siciliana', 'sierra_leone',
#        'singapore', 'sint_maarten', 'slovak_state_(1939-1945)',
#        'slovakia', 'slovenia', 'socialist_federal_republic_of_yugoslavia',
#        'socialist_republic_of_romania', 'sockel_fm2+', 'solomon_islands',
#        'somalia', 'south_africa', 'south_korea', 'south_sudan',
#        'south_vietnam', 'south_yemen', 'southern_rhodesia',
#        'soviet_union', 'soviètic', 'spain', 'spain_under_the_restoration',
#        'sri_lanka', 'ss_france', 'staffanstorp_municipality',
#        'state_of_palestine', 'statelessness', 'sudan', 'suisse_romande',
#        'sultanate_of_zanzibar', 'suriname', 'sweden', 'switzerland',
#        'syria', 'são_paulo', 'são_tomé_and_príncipe', 'tabasco', 'taiwan',
#        'tajikistan', 'tamil_eelam', 'tanzania', 'thailand',
#        'the_republic_of_abkhazia', 'third_czechoslovak_republic', 'tibet',
#        'tibet_from_1912_to_1951', 'tibetan_people', 'togo', 'tonga',
#        'transnistria', 'trinidad_and_tobago', 'tunisia', 'turkey',
#        'turkish_republic_of_northern_cyprus', 'turkmenistan',
#        'tuva_republic', 'tuvalu', 'uganda', 'ukraine',
#        'ukrainian_soviet_socialist_republic', 'ukrainians',
#        'union_of_south_africa', 'united_arab_emirates',
#        'united_federation_of_planets', 'united_kingdom',
#        'united_kingdom_of_great_britain_and_ireland',
#        'united_states_of_america', 'uruguay', 'uzbekistan', 'vanuatu',
#        'vatican_city', 'venezolano.', 'venezuela', 'vietnam', 'wales',
#        'weimar_republic', 'welsh_people', 'west_germany',
#        'western_sahara', 'yemen', 'yemen_arab_republic', 'yugoslavia',
#        'zambia', 'zimbabwe'], dtype=object)

# %%
nationality_counts = df['nationality'].value_counts() # это чисто для графика, чтобы было красивее
nationality_counts
# Out:
# nationality
# united_states_of_america       60341
# germany                        23901
# france                         17653
# united_kingdom                 15495
# italy                          12994
#                                ...
# spain_under_the_restoration        1
# british_virgin_islands             1
# liberland                          1
# croacia                            1
# são_paulo                          1
# Name: count, Length: 405, dtype: int64

# %%
nationality_indices = range(1, len(nationality_counts) + 1)

plt.figure(figsize=(12, 6))
plt.bar(nationality_indices, nationality_counts.values, color='lightcoral')

plt.xlabel('Номер национальности')
plt.ylabel('Количество строк')
plt.title('Распределение количества строк по национальностям')

plt.show()

# %% [markdown]
# ##### Большие выбросы сильно искажают данные => посмотрим медианные 80%, чтобы увеличить масштаб

# %%
D1 = nationality_counts.quantile(0.1)
D9 = nationality_counts.quantile(0.9)

lower_bound = D1
upper_bound = D9

median_80_data = nationality_counts[
    (nationality_counts >= lower_bound) & (nationality_counts <= upper_bound)
]

filtered_indices = range(1, len(median_80_data) + 1)

plt.figure(figsize=(12, 6))
plt.bar(filtered_indices, median_80_data.values, color='lightsalmon')

plt.xlabel('Номер национальности')
plt.ylabel('Количество строк')
plt.title('Распределение количества строк по национальностям (медианные 80% данных)')

plt.show()

# %% [markdown]
# #### Дополнительно посмотрим распределение года рождения просто по приколу, изучить нереальные значения

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['year_of_birth'], bins=100, color='peachpuff', edgecolor='coral')

plt.xlabel('Год рождения')
plt.ylabel('Количество людей')
plt.title('Распределение года рождения')

plt.show()

# %%
df[df['year_of_birth'] > 2020]#['image'].values[0]
# Out:
#            id          label                   nationality  \
# 87132  Q16311  James T. Kirk      united_states_of_america
# 87133  Q16341          Spock  united_federation_of_planets
#
#               date_of_birth  year_of_birth  \
# 87132  2233-03-22T00:00:00Z           2233
# 87133  2230-01-01T00:00:00Z           2230
#
#                                                    image
# 87132  https://upload.wikimedia.org/wikipedia/commons...
# 87133  https://upload.wikimedia.org/wikipedia/commons...

# %% [markdown]
# ##### Забавно, это персонажи научно-фантастического телесериала «Звёздный путь». Они нам никак не помешают, так что пусть остаются)

# %%
df[df['nationality'] == 'russia'] # ради интереса глянем своих
# Out:
#                id                  label nationality         date_of_birth  \
# 13        Q262084       Lioubov Sokolova      russia  1977-12-04T00:00:00Z
# 46        Q263867          Vera Sokolova      russia  1987-06-08T00:00:00Z
# 94        Q266271     Sainkho Namtchylak      russia  1957-03-11T00:00:00Z
# 110       Q266930        Vladimir Chagin      russia  1970-01-05T00:00:00Z
# 220       Q272120      Elvira Khasyanova      russia  1981-03-28T00:00:00Z
# ...           ...                    ...         ...                   ...
# 311470  Q56676371              Daria Kan      russia  1998-09-28T00:00:00Z
# 311481  Q56876462        Anna Galliamova      russia  1986-02-27T00:00:00Z
# 311485  Q57079716         Kirill Karkach      russia  1990-07-08T00:00:00Z
# 311525  Q58860743    Vladislav Roslyakov      russia  2000-05-02T00:00:00Z
# 311556  Q59747434  Ekaterina Fedorenkova      russia  1993-08-12T00:00:00Z
#
#         year_of_birth                                              image
# 13               1977  https://upload.wikimedia.org/wikipedia/commons...
# 46               1987  https://upload.wikimedia.org/wikipedia/commons...
# 94               1957  https://upload.wikimedia.org/wikipedia/commons...
# 110              1970  https://upload.wikimedia.org/wikipedia/commons...
# 220              1981  https://upload.wikimedia.org/wikipedia/commons...
# ...               ...                                                ...
# 311470           1998  https://upload.wikimedia.org/wikipedia/commons...
# 311481           1986  https://upload.wikimedia.org/wikipedia/commons...
# 311485           1990  https://upload.wikimedia.org/wikipedia/commons...
# 311525           2000  https://upload.wikimedia.org/wikipedia/commons...
# 311556           1993  https://upload.wikimedia.org/wikipedia/commons...
#
# [5974 rows x 6 columns]

# %%
df[df['label'] == 'Vladimir Putin'] # большой брат следит за вами
# Out:
#            id           label   nationality         date_of_birth  \
# 221348  Q7747  Vladimir Putin  soviet_union  1952-10-07T00:00:00Z
#
#         year_of_birth                                              image
# 221348           1952  https://upload.wikimedia.org/wikipedia/commons...

# %% [markdown]
# ### Пошла возня...
# ##### Пробуем привести значения в `nationality` к единому +/- адекватному виду. Создадим для этого столбец `country`, который впоследствии и будем предсказывать.

# %% [markdown]
# Можно было заметить, что в столбце с так называемыми нациями в большинстве были указаны именно названия стран, а раз это архив википедии, то, недолго думая, можно прийти к выводу, что это страны происхождения (рождения) всех этих людей, потому что именно их обычно указывают на главной странице рядом с датой рождения и именем. Так что задача предсказания по фото постепенно сводится к предсказанию именно страны происхождения человека, а это уже звучит достаточно понятно и точно.

# %%
# начнем с умного подхода: поищем совпадения в библиотеке pycountry
@lru_cache(maxsize=None)
def map_to_country(name):
    try:
        country = pycountry.countries.search_fuzzy(name)[0]
        return country.name
    except LookupError:
        return None

df['country'] = df['nationality'].apply(map_to_country)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311601 entries, 0 to 311600
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   id             311601 non-null  object
#  1   label          311601 non-null  object
#  2   nationality    311601 non-null  object
#  3   date_of_birth  311601 non-null  object
#  4   year_of_birth  311601 non-null  int64
#  5   image          311601 non-null  object
#  6   country        201315 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 16.6+ MB

# %%
missing_countries = df[df['country'].isna()]
print(missing_countries['nationality'].unique().size)
missing_countries['nationality'].unique()
# Out:
# 215
# array(['united_kingdom', 'kingdom_of_the_netherlands',
#        'united_states_of_america', 'new_zealand',
#        'socialist_federal_republic_of_yugoslavia', 'czech_republic',
#        'south_africa', "people's_republic_of_china", 'south_korea',
#        'soviet_union', 'republic_of_china_(1912–1949)', 'turkey',
#        'bosnia_and_herzegovina', 'democratic_republic_of_the_congo',
#        'western_sahara', 'republic_of_macedonia', 'yugoslavia',
#        'trinidad_and_tobago', 'ivory_coast', 'puerto_rico',
#        'northern_ireland', 'saudi_arabia', 'republic_of_the_congo',
#        'north_korea', 'antigua_and_barbuda', 'czechoslovakia',
#        'sri_lanka', 'san_marino', 'dominican_republic',
#        'state_of_palestine', 'burkina_faso',
#        'federated_states_of_micronesia', 'second_polish_republic',
#        'costa_rica', 'british_raj', 'german_democratic_republic',
#        'québec-comté', 'united_arab_emirates', 'faroe_islands',
#        'saint_kitts_and_nevis', 'hong_kong',
#        "people's_republic_of_poland", 'serbia_and_montenegro',
#        'nazi_germany', 'el_salvador', 'central_african_republic',
#        'kingdom_of_yugoslavia', 'weimar_republic', 'kingdom_of_denmark',
#        'saint_vincent_and_the_grenadines', 'papua_new_guinea',
#        'cape_verde', 'israelis', 'palestinian_national_authority',
#        'empire_of_japan', 'sierra_leone', 'east_timor',
#        'russian_soviet_federative_socialist_republic',
#        'kingdom_of_serbs,_croatians_and_slovenes', 'range_of_andia',
#        'tibet', 'mandatory_palestine', 'kingdom_of_italy',
#        'turkish_republic_of_northern_cyprus', 'kingdom_of_romania',
#        'marítimo', 'chilena', 'canadian_french', 'equatorial_guinea',
#        'transnistria', 'great_britain', 'kingdom_of_iraq', 'south_sudan',
#        'ukrainian_soviet_socialist_republic', 'egyptians', 'francia',
#        'ukrainians', 'são_tomé_and_príncipe', 'artsakh',
#        'federal_republic_of_yugoslavia', 'dominicana',
#        'armenian_soviet_socialist_republic', 'kingdom_of_egypt',
#        'francoist_spain', 'protectorate_of_bohemia_and_moravia',
#        'west_germany', 'solomon_islands', 'saint_lucia',
#        'colonial_nigeria', 'kingdom_of_hungary',
#        "people's_republic_of_hungary", 'south_vietnam', 'isle_of_man',
#        'manchukuo', 'czechoslovak_socialist_republic',
#        'british_hong_kong', 'slovak_state_(1939-1945)',
#        'kingdom_of_bulgaria', "people's_republic_of_bulgaria",
#        'sultanate_of_zanzibar', 'dutch_east_indies', 'germans',
#        'french_algeria', 'marshall_islands',
#        'byelorussian_soviet_socialist_republic',
#        'the_republic_of_abkhazia', 'japanese_people', 'welsh_people',
#        'british_people', 'rhodesia', 'hungarian',
#        'united_federation_of_planets',
#        'federation_of_rhodesia_and_nyasaland',
#        'socialist_republic_of_romania', 'kingdom_of_albania', 'katun',
#        'iraqi_kurdistan', 'siciliana', 'soviètic',
#        'first_hungarian_republic', 'union_of_south_africa',
#        'indian_people', 'cook_islands',
#        'georgian_soviet_socialist_republic', 'staffanstorp_municipality',
#        'nuu-chah-nulth', 'southern_rhodesia', 'croacia', 'liberland',
#        'british_virgin_islands', 'american_samoa', 'danish',
#        'spain_under_the_restoration', 'kingdom_of_afghanistan',
#        'first_republic_of_austria', 'british_empire', 'kingdom_of_greece',
#        'belgian_congo', 'macau', "people's_socialist_republic_of_albania",
#        'venezolano.', 'yemen_arab_republic', 'estado_novo',
#        'vatican_city', 'kenya_colony', 'tibet_from_1912_to_1951',
#        'ruanda-urundi', 'german_empire', 'ivanteyevskaya_street',
#        'kuwait_city', 'nepali',
#        'united_kingdom_of_great_britain_and_ireland', 'tuva_republic',
#        'statelessness', 'austrians', 'british_national_(overseas)',
#        'filipino_people', 'lithuanian_soviet_socialist_republic',
#        'country_of_the_kingdom_of_the_netherlands',
#        'netherlands_antilles', 'florence', 'republic_of_upper_volta',
#        'first_portuguese_republic', 'monterrey', 'colombiana',
#        "romanian_people's_republic", 'ss_france',
#        "mongolian_people's_republic", 'francais_objective_specifique',
#        'democratic_republic_of_georgia', 'mexico_city',
#        'morocco_pavilion', 'brazil–uruguay_relations',
#        'ecuador_national_football_team', 'azerbaijani', 'bangladeshis',
#        'bulgarian', 'italians', 'american_occupation_zone',
#        'republic_of_cuba_(1902–59)', 'langnau_am_albis',
#        "federal_people's_republic_of_yugoslavia",
#        'third_czechoslovak_republic', 'south_yemen', 'irish_republic',
#        'british_somaliland', 'chinese_taipei', 'plastin', 'bosniaks',
#        'tibetan_people', 'kingdom_of_mysore', 'beiyang_government',
#        'nazareth', 'afrika', 'equestria', 'suisse_romande',
#        'republika_srpska', 'san_luis_potosí', 'república_de_síria',
#        'americans', 'chileans', 'sint_maarten', 'hungarians', 'norwegian',
#        'irish', 'tamil_eelam', 'czechoslovak_republic', 'sockel_fm2+',
#        'mexicana', 'canadian_nationality_law', 'bicycle_kick',
#        'santo_domingo', 'québécois', 'cayman_islands', 'são_paulo'],
#       dtype=object)

# %% [markdown]
# Получилось много пропусков (половина из всех изначальных), что ж, придется заполнять это самостоятельно, попросим нейросеть написать нам словарь на имеющиеся у него данные, остальные поищем вручную, нам же нечего делать...

# %%
manual_mapping = {
    'united_kingdom': 'United Kingdom',
    'kingdom_of_the_netherlands': 'Netherlands',
    'united_states_of_america': 'United States',
    'new_zealand': 'New Zealand',
    'socialist_federal_republic_of_yugoslavia': 'Yugoslavia',
    'czech_republic': 'Czech Republic',
    'south_africa': 'South Africa',
    "people's_republic_of_china": 'China',
    'south_korea': 'Korea', ###
    'soviet_union': 'Russian Federation',
    'republic_of_china_(1912–1949)': 'China',
    'turkey': 'Turkey',
    'bosnia_and_herzegovina': 'Bosnia and Herzegovina',
    'democratic_republic_of_the_congo': 'Democratic Republic of the Congo',
    'western_sahara': 'Western Sahara',
    'republic_of_macedonia': 'North Macedonia',
    'yugoslavia': 'Yugoslavia',
    'trinidad_and_tobago': 'Trinidad and Tobago',
    'ivory_coast': 'Côte d\'Ivoire',
    'greenland':'Canada',
    'puerto_rico': 'Puerto Rico',
    'northern_ireland': 'United Kingdom',
    'saudi_arabia': 'Saudi Arabia',
    'republic_of_the_congo': 'Congo',
    'palau':'Philippines', ###
    'montserrat':'Cuba', ###
    'north_korea': 'Korea', ###
    'antigua_and_barbuda': 'Antigua and Barbuda',
    'liechtenstein':'Israel', ###
    'czechoslovakia': 'Czech Republic',
    'sri_lanka': 'Sri Lanka',
    'san_marino': 'San Marino',
    'dominican_republic': 'Dominican Republic',
    'state_of_palestine': 'Palestine, State of',
    'burkina_faso': 'Burkina Faso',
    'federated_states_of_micronesia': 'Micronesia, Federated States of',
    'second_polish_republic': 'Poland',
    'costa_rica': 'Costa Rica',
    'british_raj': 'India',
    'german_democratic_republic': 'Germany',
    'united_arab_emirates': 'United Arab Emirates',
    'faroe_islands': 'United kingdom', ###
    'saint_kitts_and_nevis': 'Saint Kitts and Nevis',
    'hong_kong': 'China', ###
    "people's_republic_of_poland": 'Poland',
    'serbia_and_montenegro': 'Serbia',
    'nazi_germany': 'Germany',
    'el_salvador': 'El Salvador',
    'central_african_republic': 'Central African Republic',
    'kingdom_of_yugoslavia': 'Yugoslavia',
    'weimar_republic': 'Germany',
    'kingdom_of_denmark': 'Denmark',
    'saint_vincent_and_the_grenadines': 'Saint Vincent and the Grenadines',
    'papua_new_guinea': 'Papua New Guinea',
    'cape_verde': 'Cabo Verde',
    'palestinian_national_authority': 'Palestine, State of',
    'empire_of_japan': 'Japan',
    'sierra_leone': 'Sierra Leone',
    'east_timor': 'Indonesia', ###
    'russian_soviet_federative_socialist_republic': 'Russian Federation',
    'kingdom_of_serbs,_croatians_and_slovenes': 'Yugoslavia',
    'tibet': 'China',
    'mandatory_palestine': 'Palestine, State of',
    'kingdom_of_italy': 'Italy',
    'turkish_republic_of_northern_cyprus': 'Cyprus',
    'kingdom_of_romania': 'Romania',
    'guernsey':'United Kingdom', ###
    'equatorial_guinea': 'Equatorial Guinea',
    'transnistria': 'Romania',
    'great_britain': 'United Kingdom',
    'kingdom_of_iraq': 'Iraq',
    'south_sudan': 'Sudan',
    'ukrainian_soviet_socialist_republic': 'Ukraine',
    'são_tomé_and_príncipe': 'São Tomé and Príncipe',
    'artsakh': 'Azerbaijan',
    'federal_republic_of_yugoslavia': 'Yugoslavia',
    'armenian_soviet_socialist_republic': 'Armenia',
    'kingdom_of_egypt': 'Egypt',
    'francoist_spain': 'Spain',
    'protectorate_of_bohemia_and_moravia': 'Czech Republic',
    'west_germany': 'Germany',
    'solomon_islands': 'Solomon Islands',
    'saint_lucia': 'Saint Lucia',
    'colonial_nigeria': 'Nigeria',
    'kingdom_of_hungary': 'Hungary',
    "people's_republic_of_hungary": 'Hungary',
    'south_vietnam': 'Vietnam',
    'isle_of_man': 'United Kingdom', ###
    'manchukuo': 'China',
    'laos': 'Laos',
    'czechoslovak_socialist_republic': 'Czech Republic',
    'british_hong_kong': 'China',
    'slovak_state_(1939-1945)': 'Slovakia',
    'kingdom_of_bulgaria': 'Bulgaria',
    "people's_republic_of_bulgaria": 'Bulgaria',
    'sultanate_of_zanzibar': 'Tanzania, United Republic of', ###
    'dutch_east_indies': 'Indonesia',
    'french_algeria': 'Algeria',
    'marshall_islands': 'Marshall Islands',
    'byelorussian_soviet_socialist_republic': 'Belarus',
    'japanese_people': 'Japan',
    'welsh_people': 'United Kingdom',
    'british_people': 'United Kingdom',
    'rhodesia': 'Zimbabwe',
    'hungarian': 'Hungary',
    'federation_of_rhodesia_and_nyasaland': 'Zimbabwe',
    'socialist_republic_of_romania': 'Romania',
    'kingdom_of_albania': 'Albania',
    'iraqi_kurdistan': 'Iraq',
    'union_of_south_africa': 'South Africa',
    'indian_people': 'India',
    'cook_islands': 'New Zealand', ###
    'niue': 'New Zealand', ### 
    'georgian_soviet_socialist_republic': 'Georgia',
    'southern_rhodesia': 'Zimbabwe',
    'british_virgin_islands': 'United States',
    'american_samoa': 'United States',
    'danish': 'Denmark',
    'kingdom_of_afghanistan': 'Afghanistan',
    'first_republic_of_austria': 'Austria',
    'british_empire': 'United Kingdom',
    'kingdom_of_greece': 'Greece',
    'belgian_congo': 'Democratic Republic of the Congo',
    'macau': 'China',
    "people's_socialist_republic_of_albania": 'Albania',
    'yemen_arab_republic': 'Yemen',
    'vatican_city': 'Italy',
    'kenya_colony': 'Kenya',
    'tibet_from_1912_to_1951': 'China',
    'ruanda-urundi': 'Rwanda',
    'german_empire': 'Germany',
    'nepali': 'Nepal',
    'united_kingdom_of_great_britain_and_ireland': 'United Kingdom',
    'tuva_republic': 'Russian Federation',
    'austrians': 'Austria',
    'british_national_(overseas)': 'United Kingdom',
    'filipino_people': 'Philippines',
    'lithuanian_soviet_socialist_republic': 'Lithuania',
    'country_of_the_kingdom_of_the_netherlands': 'Netherlands',
    'netherlands_antilles': 'Netherlands',
    'republic_of_upper_volta': 'Burkina Faso',
    'first_portuguese_republic': 'Portugal',
    "romanian_people's_republic": 'Romania',
    "mongolian_people's_republic": 'Mongolia',
    'democratic_republic_of_georgia': 'Georgia',
    'azerbaijani': 'Azerbaijan',
    'bangladeshis': 'Bangladesh',
    'bulgarian': 'Bulgaria',
    'italians': 'Italy',
    'american_occupation_zone': 'Germany',
    'republic_of_cuba_(1902–59)': 'Cuba',
    'south_yemen': 'Yemen',
    'irish_republic': 'Ireland',
    'british_somaliland': 'Somalia',
    'chinese_taipei': 'China',
    'bosniaks': 'Bosnia and Herzegovina',
    'tibetan_people': 'China',
    'kingdom_of_mysore': 'India',
    'beiyang_government': 'China',
    'afrika': 'South Africa',
    'americans': 'United States',
    'chileans': 'Chile',
    'sint_maarten': 'Netherlands',
    'hungarians': 'Hungary',
    'norwegian': 'Norway',
    'irish': 'Ireland',
    'czechoslovak_republic': 'Czech Republic',
    'mexicana': 'Mexico',
    'cayman_islands': 'Cuba',
    'são_paulo': 'Brazil',
    'québec-comté': 'Canada',
    'israelis': 'Israel',
    'range_of_andia': 'Spain',
    'anguilla':'Cuba',
    'marítimo': 'Portugal',
    'chilena': 'Chile',
    'canadian_french': 'Canada',
    'egyptians': 'Egypt',
    'francia': 'France',
    'ukrainians': 'Ukraine',
    'dominicana': 'Dominican Republic',
    'kurdistan': 'Turkey',
    'germans': 'Germany',
    'the_republic_of_abkhazia': 'Georgia', #### упс...
    'united_federation_of_planets': 'United States', # легенда
    'katun': 'Russian Federation',
    'siciliana': 'Italy',
    'soviètic': 'Russian Federation',
    'first_hungarian_republic': 'Hungary',
    'staffanstorp_municipality': 'Sweden',
    'nuu-chah-nulth': 'Canada',
    'croacia': 'Croatia',
    'liberland': 'Czech Republic',
    'spain_under_the_restoration': 'Spain',
    'venezolano.': 'Venezuela, Bolivarian Republic of',
    'estado_novo': 'Portugal',
    'ivanteyevskaya_street': 'Russian Federation',
    'kuwait_city': 'Kuwait',
    'florence': 'Italy',
    'monterrey': 'Mexico',
    'moldova':'Romania', ###
    'colombiana': 'Colombia',
    'ss_france': 'France',
    'francais_objective_specifique': 'France',
    'mexico_city': 'Mexico',
    'morocco_pavilion': 'Morocco',
    'brazil–uruguay_relations': 'Brazil',
    'ecuador_national_football_team': 'Ecuador',
    'langnau_am_albis': 'Switzerland',
    "federal_people's_republic_of_yugoslavia": 'Yugoslavia',
    'third_czechoslovak_republic': 'Czech Republic',
    'plastin': 'Romania',
    'nazareth': 'Israel',
    'korea':'Korea', ###
    'suisse_romande': 'Switzerland',
    'republika_srpska': 'Bosnia and Herzegovina',
    'san_luis_potosí': 'Mexico',
    'república_de_síria': 'Syrian Arab Republic',
    'tamil_eelam': 'Sri Lanka',
    'sockel_fm2+': 'Spain', # немного непонятно при чем тут розетка...
    'canadian_nationality_law': 'Canada',
    'bicycle_kick': 'Chile',
    'santo_domingo': 'Dominican Republic',
    'québécois': 'Canada',
}

# %%
# всего 2 часа потраченного времени, и вот он - самый большой словарь стран
df['country'] = df['nationality'].map(manual_mapping).combine_first(df['country'])

# %%
df[df['country'].isna()]
# Out:
#                id             label    nationality         date_of_birth  \
# 171177  Q18175132  Eliana Rubashkyn  statelessness  1988-06-25T00:00:00Z
# 171460  Q18591201    Glen L Roberts  statelessness  1962-05-05T00:00:00Z
# 187439   Q1187597       Denis Pécic  statelessness  1928-10-08T00:00:00Z
# 257922  Q15141696  Twilight Sparkle      equestria  1998-08-23T00:00:00Z
#
#         year_of_birth                                              image  \
# 171177           1988  https://upload.wikimedia.org/wikipedia/commons...
# 171460           1962  https://upload.wikimedia.org/wikipedia/commons...
# 187439           1928  https://upload.wikimedia.org/wikipedia/commons...
# 257922           1998  https://upload.wikimedia.org/wikipedia/commons...
#
#        country
# 171177    None
# 171460    None
# 187439    None
# 257922    None

# %% [markdown]
# Остались совсем уникальные случаи, мне было не лень посмотреть и их...

# %%
df.loc[df["label"] == "Eliana Rubashkyn", "country"] = "Colombia"
df.loc[df["label"] == "Glen L Roberts", "country"] = "United States"
df.loc[df["label"] == "Denis Pécic", "country"] = "France"

# %%
df[df['country'].isna()]['image'].values[0]
# Out:
# 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Twilight_Sparkle_Cuttie_Mark.svg/200px-Twilight_Sparkle_Cuttie_Mark.svg'

# %% [markdown]
# Эту малышку придется дропнуть, чтобы не портила статистику, но Искорка в наших сердцах...

# %%
df = df.dropna(subset=['country'])

# %% [markdown]
# #### Итак, итоговое распределение по странам:

# %%
print(df['country'].unique().size)
df['country'].unique()
# Out:
# 197
# array(['Canada', 'Argentina', 'United Kingdom', 'Norway',
#        'Iran, Islamic Republic of', 'Netherlands', 'United States',
#        'New Zealand', 'Greece', 'Sweden', 'Germany', 'Russian Federation',
#        'Estonia', 'Ukraine', 'Nigeria', 'Jamaica',
#        'Venezuela, Bolivarian Republic of', 'Denmark', 'Switzerland',
#        'Finland', 'France', 'Belgium', 'Romania', 'Italy', 'Poland',
#        'India', 'Ireland', 'Yugoslavia', 'Japan', 'Hungary',
#        'Czech Republic', 'South Africa', 'Mexico', 'Australia', 'Chile',
#        'Israel', 'Austria', 'Spain', 'Lebanon', 'China', 'Korea',
#        'Serbia', 'Georgia', 'Croatia', 'Turkey', 'Brazil', 'Portugal',
#        'Senegal', 'Belarus', 'Nicaragua', 'Bulgaria', 'Colombia',
#        'Thailand', 'Slovenia', 'Latvia', 'Bosnia and Herzegovina',
#        'Democratic Republic of the Congo', 'Western Sahara', 'Cyprus',
#        'Albania', 'Lithuania', 'Taiwan, Province of China', 'Uruguay',
#        'North Macedonia', 'Iceland', 'Peru', 'Trinidad and Tobago',
#        "Côte d'Ivoire", 'Zambia', 'Tunisia', 'Malta', 'Somalia', 'Libya',
#        'Morocco', 'Djibouti', 'Angola', 'Barbados', 'Panama',
#        'Puerto Rico', 'Egypt', 'Andorra', 'Ecuador', 'Algeria', 'Mali',
#        'Ghana', 'Cuba', 'Kenya', 'Cameroon', 'Haiti', 'Nepal',
#        'Saudi Arabia', 'Azerbaijan', 'Afghanistan', 'Ethiopia',
#        'Slovakia', 'Iraq', 'Luxembourg', 'Philippines', 'Pakistan',
#        'Mongolia', 'Kuwait', 'Sudan', 'Armenia', 'Myanmar', 'Congo',
#        'Honduras', 'Syrian Arab Republic', 'Antigua and Barbuda', 'Benin',
#        'Sri Lanka', 'Bolivia, Plurinational State of', 'San Marino',
#        'Cambodia', 'Kazakhstan', 'Zimbabwe', 'Malaysia',
#        'Dominican Republic', 'Paraguay', 'Indonesia',
#        'Palestine, State of', 'Burkina Faso',
#        'Micronesia, Federated States of', 'Viet Nam', 'Burundi',
#        'Costa Rica', 'Tanzania, United Republic of', 'Singapore',
#        'Bahamas', 'Laos', 'Montenegro', 'Jordan', 'Guinea', 'Namibia',
#        'Bahrain', 'Guatemala', 'Monaco', 'Gambia', 'Uzbekistan',
#        'United Arab Emirates', 'United kingdom', 'Nauru',
#        'Saint Kitts and Nevis', 'Dominica', 'Suriname', 'Bangladesh',
#        'Qatar', 'Uganda', 'Chad', 'Tonga', 'Guyana', 'El Salvador',
#        'Turkmenistan', 'Central African Republic', 'Kiribati',
#        'Madagascar', 'Saint Vincent and the Grenadines', 'Rwanda',
#        'Papua New Guinea', 'Cabo Verde', 'Liberia', 'Togo', 'Kyrgyzstan',
#        'Sierra Leone', 'Samoa', 'Mauritius', 'Mozambique', 'Tuvalu',
#        'Eswatini', 'Mauritania', 'Yemen', 'Aruba', 'Lesotho', 'Oman',
#        'Grenada', 'Botswana', 'Fiji', 'Gabon', 'Equatorial Guinea',
#        'Malawi', 'Eritrea', 'Guam', 'Tajikistan', 'Guinea-Bissau',
#        'Bhutan', 'Brunei Darussalam', 'São Tomé and Príncipe', 'Belize',
#        'Seychelles', 'Maldives', 'Bermuda', 'Comoros', 'Solomon Islands',
#        'Saint Lucia', 'Vietnam', 'Vanuatu', 'Marshall Islands',
#        'Gibraltar'], dtype=object)

# %% [markdown]
# #### Посмотрим, как поменялся график

# %%
country_counts = df['country'].value_counts()

country_indices = range(1, len(country_counts) + 1)

plt.figure(figsize=(12, 6))
plt.bar(country_indices, country_counts.values, color='lightcoral')

plt.xlabel('Номер страны')
plt.ylabel('Количество строк')
plt.title('Распределение количества строк по странам')

plt.show()

# %% [markdown]
# #### Все еще есть длинный хвост стран с малекьким количеством строк. Попробуем сгруппировать редкие страны (где меньше 50 строк) по географическому признаку, сократив таким образом количество классов и увеличив количество данных для малых классов. Это повысит наши шансы нормально обучить модель. Снова прибегнем к словарю.

# %%
filtered_counts = country_counts[country_counts < 50] 
filtered_counts
# Out:
# country
# Gambia                              49
# Cabo Verde                          49
# Yemen                               49
# Madagascar                          48
# Tuvalu                              45
# Kyrgyzstan                          44
# Barbados                            43
# Bahamas                             41
# Gabon                               38
# Liberia                             38
# Sierra Leone                        37
# Mozambique                          36
# Eritrea                             35
# Togo                                32
# Samoa                               31
# Mauritius                           29
# Botswana                            28
# Central African Republic            26
# Guyana                              25
# San Marino                          22
# Laos                                22
# Monaco                              21
# Tajikistan                          21
# Antigua and Barbuda                 20
# Grenada                             20
# Mauritania                          19
# Maldives                            19
# Papua New Guinea                    19
# Belize                              19
# Burundi                             19
# Guinea-Bissau                       18
# Seychelles                          18
# Saint Kitts and Nevis               17
# Bhutan                              16
# Chad                                16
# Malawi                              16
# Solomon Islands                     14
# Comoros                             14
# Turkmenistan                        14
# Oman                                13
# Lesotho                             13
# Western Sahara                      11
# Equatorial Guinea                   10
# Guam                                10
# São Tomé and Príncipe               10
# Djibouti                            10
# Saint Lucia                         10
# Marshall Islands                     9
# Saint Vincent and the Grenadines     9
# Brunei Darussalam                    9
# Bermuda                              9
# Vanuatu                              8
# Nauru                                8
# Micronesia, Federated States of      8
# Eswatini                             6
# Kiribati                             5
# Aruba                                5
# Gibraltar                            4
# Vietnam                              2
# Name: count, dtype: int64

# %%
# словарь для группировки редких стран
country_groups = {
    'Caribbean': [
        'Antigua and Barbuda', 'Bahamas', 'Barbados', 
        'Grenada', 'Saint Kitts and Nevis', 'Saint Lucia',
        'Saint Vincent and the Grenadines', 'Aruba', 'Bermuda',
        'Belize', 'Guyana'
    ],
    'Pacific Islands': [
        'Kiribati', 'Marshall Islands', 'Micronesia, Federated States of',
        'Nauru', 'Guam', 'Solomon Islands', 'Tuvalu', 'Vanuatu',
        'Papua New Guinea', 'Samoa'
    ],
    'African Small States': [
        'Botswana', 'Burundi', 'Cabo Verde', 'Comoros',
        'Djibouti', 'Equatorial Guinea', 'Eswatini', 'Gabon', 'Gambia', 'Eritrea',
        'Guinea-Bissau', 'Lesotho', 'Malawi', 'Mauritania', 'Mauritius', 'Mozambique',
        'São Tomé and Príncipe', 'Seychelles', 'Togo', 'Madagascar',
        'Central African Republic', 'Chad', 'Sierra Leone', 'Liberia'                               
    ],
    'Central Asia': [
        'Kyrgyzstan', 'Tajikistan', 'Turkmenistan', 'Uzbekistan'
    ],
    'Middle East Small States': [
        'Brunei Darussalam', 'Oman', 'Qatar', 'Western Sahara', 'Yemen'
    ],
    'Other Europe': [
        'Gibraltar', 'Monaco', 'San Marino'
    ],
    'Other Asia': [
        'Bhutan', 'Maldives', 'Laos', 'Vietnam'
    ]
}

# %%
keep_individual = country_counts[country_counts > 49].index.tolist() #названия стран где 50 и больше строк не меняем
def group_country(country):
    if country in keep_individual:
        return country
    for group, countries in country_groups.items():
        if country in countries:
            return group
    return 'Other'  #на всякий случай

df.loc[:, 'country'] = df['country'].apply(group_country)

# %%
print(df['country'].unique().size)
df['country'].unique()
# Out:
# 145
# array(['Canada', 'Argentina', 'United Kingdom', 'Norway',
#        'Iran, Islamic Republic of', 'Netherlands', 'United States',
#        'New Zealand', 'Greece', 'Sweden', 'Germany', 'Russian Federation',
#        'Estonia', 'Ukraine', 'Nigeria', 'Jamaica',
#        'Venezuela, Bolivarian Republic of', 'Denmark', 'Switzerland',
#        'Finland', 'France', 'Belgium', 'Romania', 'Italy', 'Poland',
#        'India', 'Ireland', 'Yugoslavia', 'Japan', 'Hungary',
#        'Czech Republic', 'South Africa', 'Mexico', 'Australia', 'Chile',
#        'Israel', 'Austria', 'Spain', 'Lebanon', 'China', 'Korea',
#        'Serbia', 'Georgia', 'Croatia', 'Turkey', 'Brazil', 'Portugal',
#        'Senegal', 'Belarus', 'Nicaragua', 'Bulgaria', 'Colombia',
#        'Thailand', 'Slovenia', 'Latvia', 'Bosnia and Herzegovina',
#        'Democratic Republic of the Congo', 'Middle East Small States',
#        'Cyprus', 'Albania', 'Lithuania', 'Taiwan, Province of China',
#        'Uruguay', 'North Macedonia', 'Iceland', 'Peru',
#        'Trinidad and Tobago', "Côte d'Ivoire", 'Zambia', 'Tunisia',
#        'Malta', 'Somalia', 'Libya', 'Morocco', 'African Small States',
#        'Angola', 'Caribbean', 'Panama', 'Puerto Rico', 'Egypt', 'Andorra',
#        'Ecuador', 'Algeria', 'Mali', 'Ghana', 'Cuba', 'Kenya', 'Cameroon',
#        'Haiti', 'Nepal', 'Saudi Arabia', 'Azerbaijan', 'Afghanistan',
#        'Ethiopia', 'Slovakia', 'Iraq', 'Luxembourg', 'Philippines',
#        'Pakistan', 'Mongolia', 'Kuwait', 'Sudan', 'Armenia', 'Myanmar',
#        'Congo', 'Honduras', 'Syrian Arab Republic', 'Benin', 'Sri Lanka',
#        'Bolivia, Plurinational State of', 'Other Europe', 'Cambodia',
#        'Kazakhstan', 'Zimbabwe', 'Malaysia', 'Dominican Republic',
#        'Paraguay', 'Indonesia', 'Palestine, State of', 'Burkina Faso',
#        'Pacific Islands', 'Viet Nam', 'Costa Rica',
#        'Tanzania, United Republic of', 'Singapore', 'Other Asia',
#        'Montenegro', 'Jordan', 'Guinea', 'Namibia', 'Bahrain',
#        'Guatemala', 'Uzbekistan', 'United Arab Emirates',
#        'United kingdom', 'Dominica', 'Suriname', 'Bangladesh', 'Qatar',
#        'Uganda', 'Tonga', 'El Salvador', 'Central Asia', 'Rwanda', 'Fiji'],
#       dtype=object)

# %% [markdown]
# #### Итак, наш список сократился до 145 стран (классов), где не менее 45 строк в каждом (можно проверить)

# %%
df['country'].value_counts()
# Out:
# country
# United States     60348
# Germany           24165
# France            17659
# United Kingdom    15922
# Italy             13042
#                   ...
# Tonga                52
# Benin                52
# Zambia               50
# Rwanda               50
# Other Europe         47
# Name: count, Length: 145, dtype: int64

# %%
country_counts = df['country'].value_counts()

country_indices = range(1, len(country_counts) + 1)

plt.figure(figsize=(12, 6))
plt.bar(country_indices, country_counts.values, color='lightcoral')

plt.xlabel('Номер страны')
plt.ylabel('Количество строк')
plt.title('Распределение количества строк по странам')

plt.show()

# %%
# import aiohttp
# import asyncio
# import pandas as pd
# import os
# from PIL import Image
# from io import BytesIO
# from tqdm.asyncio import tqdm_asyncio
#
# dataset_root = "dataset_mashaV0.1"
# SEM_LIMIT = 100  # максимальное число одновременных запросов
#
# # Асинхронная проверка доступности URL
# async def is_url_accessible(session, url, headers, semaphore):
#     async with semaphore:
#         try:
#             async with session.get(url, headers=headers, timeout=5) as resp:
#                 return resp.status == 200
#         except:
#             return False
#
# # Асинхронное скачивание и сохранение
# async def download_image(session, row, index, headers, semaphore):
#     url = row['image']
#     class_name = str(row['country']).strip().lower().replace(" ", "_")
#     class_dir = os.path.join(dataset_root, class_name)
#     os.makedirs(class_dir, exist_ok=True)
#
#     async with semaphore:
#         try:
#             async with session.get(url, headers=headers, timeout=5) as resp:
#                 if resp.status == 200:
#                     content = await resp.read()
#                     image = Image.open(BytesIO(content)).convert('RGB')
#                     image.save(os.path.join(class_dir, f"{index}.jpg"))
#         except Exception as e:
#             print(f"[{index}] Ошибка: {e}")
#
# # Главная асинхронная функция
# async def process_all(df):
#     headers = {
#         'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
#         'Referer': 'https://google.com'
#     }
#
#     semaphore = asyncio.Semaphore(SEM_LIMIT)
#
#     async with aiohttp.ClientSession(headers=headers) as session:
#         # --- Валидация URL ---
#         tasks_check = [
#             is_url_accessible(session, url, headers, semaphore) if pd.notna(url) else False
#             for url in df['image']
#         ]
#         valid_mask = await tqdm_asyncio.gather(*tasks_check, desc="Проверка URL")
#         df_valid = df[valid_mask].reset_index(drop=True)
#
#         # --- Загрузка изображений ---
#         tasks_download = [
#             download_image(session, row, idx, headers, semaphore)
#             for idx, row in df_valid.iterrows()
#         ]
#         await tqdm_asyncio.gather(*tasks_download, desc="Загрузка изображений")
#
#     return df_valid

# %%
import aiohttp
import asyncio
import pandas as pd
import os
from PIL import Image, UnidentifiedImageError
from io import BytesIO
from tqdm.asyncio import tqdm_asyncio
from urllib.parse import quote, urlsplit, urlunsplit
import random

dataset_root = "dataset_masha_200000_V0.2"
SEM_LIMIT = 50  # максимум одновременных задач

def safe_url(url):
    try:
        parts = urlsplit(url)
        safe_path = quote(parts.path)
        return urlunsplit((parts.scheme, parts.netloc, safe_path, parts.query, parts.fragment))
    except:
        return url  # если не удалось — оставить как есть

async def is_url_accessible(session, url, semaphore):
    async with semaphore:
        try:
            url = safe_url(url)
            async with session.get(url, timeout=5) as resp:
                return resp.status == 200
        except:
            return False

async def download_image(session, row, index, semaphore):
    url = safe_url(row['image'])
    class_name = str(row['country']).strip().lower().replace(" ", "_")
    class_dir = os.path.join(dataset_root, class_name)
    os.makedirs(class_dir, exist_ok=True)

    async with semaphore:
        await asyncio.sleep(random.uniform(0.1, 0.3))  # ⬅️ здесь задержка

        try:
            async with session.get(url, timeout=5) as resp:
                if resp.status == 200:
                    content = await resp.read()
                    try:
                        image = Image.open(BytesIO(content)).convert('RGB')
                        image.save(os.path.join(class_dir, f"{index}.jpg"))
                    except UnidentifiedImageError:
                        print(f"[{index}] Нераспознанный формат изображения")
                else:
                    print(f"[{index}] HTTP статус: {resp.status}")
        except Exception as e:
            print(f"[{index}] Ошибка скачивания: {e}")

async def process_all(df):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Referer': 'https://google.com'
    }

    semaphore = asyncio.Semaphore(SEM_LIMIT)

    async with aiohttp.ClientSession(headers=headers) as session:
        # Проверка доступности
        tasks_check = [
            is_url_accessible(session, url, semaphore) if pd.notna(url) else False
            for url in df['image']
        ]
        valid_mask = await tqdm_asyncio.gather(*tasks_check, desc="Проверка URL")
        df_valid = df[valid_mask].reset_index(drop=True)

        # Загрузка изображений
        # df = df[df['image'].notna() & df['country'].notna()]
        tasks_download = [
            download_image(session, row, idx, semaphore)
            for idx, row in df_valid.iterrows()
        ]
        await tqdm_asyncio.gather(*tasks_download, desc="Загрузка изображений")

    return df_valid

# %%
import nest_asyncio
nest_asyncio.apply()
new_df = await process_all(df[:100000])
# Out:
# Проверка URL: 100%|██████████| 100000/100000 [02:14<00:00, 743.73it/s]
# Загрузка изображений: 100%|██████████| 11810/11810 [01:18<00:00, 151.39it/s]

# %%
country_counts = new_df['country'].value_counts()

country_indices = range(1, len(country_counts) + 1)

plt.figure(figsize=(12, 6))
plt.bar(country_indices, country_counts.values, color='lightcoral')

plt.xlabel('Номер страны')
plt.ylabel('Количество строк')
plt.title('Распределение количества строк по странам')

plt.show()
