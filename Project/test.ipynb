# %%
# Открыть файл для записи (если файла нет — создастся)
with open("example.txt", "w", encoding="utf-8") as f:
    f.write("Привет, мир!\n")
    f.write("Это пример создания файла.\n")
print("OK")
# Out:
# OK
